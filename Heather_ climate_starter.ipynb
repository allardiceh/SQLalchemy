# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
Base = automap_base()
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# reflect an existing database into a new model
Base.prepare(engine, reflect=True)

# identify the keys
Base.classes.keys()

# Save references to each table
station = Base.classes.station
measurement = Base.classes.measurement

# Create our session (link) from Python to the DB
session=Session(engine)
# Out:
# /Users/heatherallardice/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.measurement, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/heatherallardice/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.station, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Find Percipitation by date info
results = session.query(measurement.date, measurement.prcp) 
for row in results:
    print(row)
# Out:
# ('2010-01-01', 0.08)
# ('2010-01-02', 0.0)
# ('2010-01-03', 0.0)
# ('2010-01-04', 0.0)
# ('2010-01-06', None)
# ('2010-01-07', 0.06)
# ('2010-01-08', 0.0)
# ('2010-01-09', 0.0)
# ('2010-01-10', 0.0)
# ('2010-01-11', 0.01)
# ('2010-01-12', 0.0)
# ('2010-01-14', 0.0)
# ('2010-01-15', 0.0)
# ('2010-01-16', 0.0)
# ('2010-01-17', 0.0)
# ('2010-01-18', 0.0)
# ('2010-01-19', 0.0)
# ('2010-01-20', 0.0)
# ('2010-01-21', 0.0)
# ('2010-01-22', 0.0)
# ('2010-01-23', 0.0)
# ('2010-01-24', 0.01)
# ('2010-01-25', 0.0)
# ('2010-01-26', 0.04)
# ('2010-01-27', 0.12)
# ('2010-01-28', 0.0)
# ('2010-01-30', None)
# ('2010-01-31', 0.03)
# ('2010-02-01', 0.01)
# ('2010-02-03', None)
# ('2010-02-04', 0.01)
# ('2010-02-05', 0.0)
# ('2010-02-06', 0.0)
# ('2010-02-07', 0.0)
# ('2010-02-08', 0.0)
# ('2010-02-09', 0.0)
# ('2010-02-11', 0.0)
# ('2010-02-12', 0.02)
# ('2010-02-13', 0.01)
# ('2010-02-14', 0.0)
# ('2010-02-15', 0.0)
# ('2010-02-16', 0.0)
# ('2010-02-17', 0.0)
# ('2010-02-19', None)
# ...

# %%
#put search results into a dataframe
df=pd.DataFrame(results[:330])
df.head()
df.tail()
# Out:
#            date  prcp
# 325  2010-12-27  0.13
# 326  2010-12-28  0.55
# 327  2010-12-29  0.06
# 328  2010-12-30  0.01
# 329  2010-12-31  0.00

# %%
#df.plot(x ='date', y='prcp', kind = 'scatter')##simple graph code

plt.scatter(df['date'], df['prcp'], marker='o', s=20, c='blue', edgecolors='black',  alpha=.75)
# Format axis/labels.
plt.title('Precipitation by Date 2010')
plt.ylabel('Precipitation')
plt.xlabel('Date')
plt.grid(True)

# Save the figure.
plt.savefig('Messy_Rain2010.png')

plt.show()

# %%
# Calculate the date 1 year ago from the last data point in the database
#locating the value
last = df.date.iloc[-1]
print(last)
# import datetime this module is already in python
import datetime

# use datetime to figure out past dates

delta=datetime.timedelta(days=365)
last_date = datetime.datetime(2017, 8, 23)
print(last_date - delta)
# Out:
# 2017-08-23
# 2016-08-23 00:00:00

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

df_precipitation_summary=df.describe()
print(df_precipitation_summary)
# Out:
#              prcp
# count  319.000000
# mean     0.030909
# std      0.138105
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.010000
# max      1.580000

# %%
# Design a query to show how many unique stations are available in this dataset?
Unique_stations = session.query(station).count()
print(Unique_stations)
# Out:
# 9

# %%
# Creating the data set 
sel = [ measurement.date, measurement.prcp,measurement.tobs,  station.station, station.name, station.latitude, station.longitude, station.elevation]
same_station = session.query(*sel).filter(measurement.station == station.station).limit(3000).all()
# making it into a dataframe 
df_join=pd.DataFrame(same_station[:3000])
df_join
# Out:
#             date  prcp  tobs      station                  name  latitude  \
# 0     2010-01-01  0.08  65.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 1     2010-01-02  0.00  63.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 2     2010-01-03  0.00  74.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 3     2010-01-04  0.00  76.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 4     2010-01-06   NaN  73.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# ...          ...   ...   ...          ...                   ...       ...
# 2995  2010-10-02  0.16  76.0  USC00513117  KANEOHE 838.1, HI US   21.4234
# 2996  2010-10-03  0.07  82.0  USC00513117  KANEOHE 838.1, HI US   21.4234
# 2997  2010-10-04  0.06  76.0  USC00513117  KANEOHE 838.1, HI US   21.4234
# 2998  2010-10-05  0.07  77.0  USC00513117  KANEOHE 838.1, HI US   21.4234
# 2999  2010-10-06  0.00  76.0  USC00513117  KANEOHE 838.1, HI US   21.4234
#
#       longitude  elevation
# 0     -157.8168        3.0
# ...

# %%
# Creating the data set 
# limiting results to a date range and to the most frequent station
# note most frequesnt station was determined with a valu count of the database in teh date range and then used as a filter. 
sel = [ measurement.date, measurement.prcp,measurement.tobs,  station.station, station.name, station.latitude, station.longitude, station.elevation]
same_station1 = session.query(*sel).filter(measurement.station == station.station).filter(measurement.date>'2016-08-23').filter (station.station=='USC00519397').all()




df_join1=pd.DataFrame(same_station1[:3000])
df_join1
# Out:
#            date  prcp  tobs      station                  name  latitude  \
# 0    2016-08-24  0.08  79.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 1    2016-08-25  0.08  80.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 2    2016-08-26  0.00  79.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 3    2016-08-27  0.00  77.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 4    2016-08-28  0.01  78.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# ..          ...   ...   ...          ...                   ...       ...
# 355  2017-08-19  0.00  79.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 356  2017-08-20  0.00  81.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 357  2017-08-21  0.00  81.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 358  2017-08-22  0.00  82.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
# 359  2017-08-23  0.00  81.0  USC00519397  WAIKIKI 717.2, HI US   21.2716
#
#      longitude  elevation
# 0    -157.8168        3.0
# 1    -157.8168        3.0
# ...

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
Station_counts=df_join["station"].value_counts()
# List the stations and the counts in descending order. There is only one station in the choosen year
Station_counts
# Out:
# USC00519397    2724
# USC00513117     276
# Name: station, dtype: int64

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
min=df_join['tobs'].min()

# highest temperature recorded, 
max=df_join['tobs'].max()

#average temperature of the most active station?

mean=df_join['tobs'].mean()

f'The lowest temperature is {min}.  '\
f'The highest temperature is {max}.  '\
f'The average tempertaure is {mean}.'
# Out:
# 'The lowest temperature is 56.0.  The highest temperature is 87.0.  The average tempertaure is 74.36533333333334.'

# %%
# Choose the station with the highest number of temperature observations.
# see out put from [131]. Station USC00519397 has the most values for the range 
# Query the last 12 months of temperature observation data for this station 
station_97 = session.query(measurement.tobs, measurement.date, measurement.station).filter_by(station='USC00519397')
for row in station_97:
    print(row)
# Out:
# (65.0, '2010-01-01', 'USC00519397')
# (63.0, '2010-01-02', 'USC00519397')
# (74.0, '2010-01-03', 'USC00519397')
# (76.0, '2010-01-04', 'USC00519397')
# (73.0, '2010-01-06', 'USC00519397')
# (70.0, '2010-01-07', 'USC00519397')
# (64.0, '2010-01-08', 'USC00519397')
# (68.0, '2010-01-09', 'USC00519397')
# (73.0, '2010-01-10', 'USC00519397')
# (64.0, '2010-01-11', 'USC00519397')
# (61.0, '2010-01-12', 'USC00519397')
# (66.0, '2010-01-14', 'USC00519397')
# (65.0, '2010-01-15', 'USC00519397')
# (68.0, '2010-01-16', 'USC00519397')
# (64.0, '2010-01-17', 'USC00519397')
# (72.0, '2010-01-18', 'USC00519397')
# (66.0, '2010-01-19', 'USC00519397')
# (66.0, '2010-01-20', 'USC00519397')
# (69.0, '2010-01-21', 'USC00519397')
# (67.0, '2010-01-22', 'USC00519397')
# (67.0, '2010-01-23', 'USC00519397')
# (71.0, '2010-01-24', 'USC00519397')
# (67.0, '2010-01-25', 'USC00519397')
# (76.0, '2010-01-26', 'USC00519397')
# (68.0, '2010-01-27', 'USC00519397')
# (72.0, '2010-01-28', 'USC00519397')
# ...

# %%
#put search results into a dataframe
df_stat_97=pd.DataFrame(station_97)
df_stat_97.head()
df_stat_97.tail()
# Out:
#       tobs        date      station
# 2719  79.0  2017-08-19  USC00519397
# 2720  81.0  2017-08-20  USC00519397
# 2721  81.0  2017-08-21  USC00519397
# 2722  82.0  2017-08-22  USC00519397
# 2723  81.0  2017-08-23  USC00519397

# %%
#plot the results as a histogram
plt.scatter(df_stat_97['date'], df_stat_97['tobs'], marker='o', s=20, c='r', edgecolors='black', alpha=.75)
# Format axis/labels.
plt.title('Temperature by Date')
plt.ylabel('Tempurature')
plt.xlabel('Date')
plt.grid(True)

# Save the figure.
plt.savefig('Temp_Graph.png')

plt.show()

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
